# %% [markdown]
# # Importing Data Using Pandas
#
# ## Introduction
#
# We've already used Pandas to import data in previous lessons, but in this lesson we'll take a little longer to dive into what's actually going on.
#
# ## Objectives
# You will be able to:
# * Import data from csv files and Excel files
# * Understand and explain key arguments for imports
# * Save information to csv and Excel files
# * Access data within a Pandas DataFrame (print() and .head())
#
# ## Loading Pandas
#
# As usual, we import pandas under the standard alias pd

# %%
import pandas as pd

# %% [markdown]
# ## Importing Data
#
# There are a few main functions for importing data into a pandas DataFrame including:
#
# * `pd.read_csv()`
# * `pd.read_excel()`
# * `pd.read_json()`
# * `pd.DataFrame.from_dict()`
#
# Most of these methods are fairly straightforward; you use `.read_csv()` for csv files, `.read_excel()` for excel files (both new and old .xlx and .xlsx) and `.read_json()` for json files. That said, there are a few nuances you should know about. The first is that the `.read_csv()` format can be used for any plain-text delimited file. This may include (but is not limited to) pipe (|) delimited files (.psv) and tab separated files (.tsv).
#
# Let's look at an example by investigating a file, bp.txt, stored in the Data folder.

# %%
df = pd.read_csv('Data/bp.txt', delimiter='\t')
df.head()
# Out:
#    Pt   BP  Age  Weight   BSA  Dur  Pulse  Stress
# 0   1  105   47    85.4  1.75  5.1     63      33
# 1   2  115   49    94.2  2.10  3.8     70      14
# 2   3  116   49    95.3  1.98  8.2     72      10
# 3   4  117   50    94.7  2.01  5.8     73      99
# 4   5  112   51    89.4  1.89  7.0     72      95

# %% [markdown]
# This example shows that the data was tab delimited (\t), so an appropriate file extension could have also been .tsv. Once we've loaded the dataset, we can export it to any format we would like with the related methods:
#
# * `df.to_csv()`
# * `df.to_excel()`
# * `df.to_json()`
# * `df.to_dict()`
#
# There are also several other options available, but these are the most common.
#
# ## Skipping and Limiting Rows
#
# Another feature that you may have to employ is skipping rows when there is metadata stored at the top of a file. You can do this using the optional parameter `skiprows`. Similarly, if you want to only load a portion of a large file as an initial preview, you can use the `nrows` parameter.

# %%
df = pd.read_csv('Data/ACS_16_5YR_B24011_with_ann.csv', nrows=100)
df.head()
# Out:
#            GEO.id GEO.id2        GEO.display-label         HD01_VD01  \
# 0              Id     Id2                Geography  Estimate; Total:
# 1  0500000US01001   01001  Autauga County, Alabama             33267
# 2  0500000US01003   01003  Baldwin County, Alabama             31540
# 3  0500000US01005   01005  Barbour County, Alabama             26575
# 4  0500000US01007   01007     Bibb County, Alabama             30088
#
#                  HD02_VD01                                          HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Management, business, scien...
# 1                     2306                                              48819
# 2                      683                                              49524
# 3                     1653                                              41652
# 4                     2224                                              40787
#
#                                            HD02_VD02  \
# 0  Margin of Error; Total: - Management, business...
# 1                                               1806
# 2                                               1811
# 3                                               2638
# 4                                               2896
#
#                                            HD01_VD03  \
# 0  Estimate; Total: - Management, business, scien...
# 1                                              55557
# 2                                              57150
# 3                                              51797
# 4                                              50069
#
#                                            HD02_VD03  \
# 0  Margin of Error; Total: - Management, business...
# 1                                               4972
# 2                                               6980
# 3                                               5980
# 4                                              12841
#
#                                            HD01_VD04  \
# 0  Estimate; Total: - Management, business, scien...
# 1                                              63333
# 2                                              63422
# 3                                              52775
# 4                                              67917
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                            HD01_VD32  \
# 0  Estimate; Total: - Natural resources, construc...
# 1                                              31402
# 2                                              35603
# 3                                              37847
# 4                                              45952
#
#                                            HD02_VD32  \
# 0  Margin of Error; Total: - Natural resources, c...
# 1                                               5135
# 2                                               3882
# 3                                              11189
# 4                                               5622
#
#                                            HD01_VD33  \
# 0  Estimate; Total: - Production, transportation,...
# 1                                              35594
# 2                                              30549
# 3                                              26094
# 4                                              28983
#
#                                            HD02_VD33  \
# 0  Margin of Error; Total: - Production, transpor...
# 1                                               3034
# 2                                               1606
# 3                                               4884
# 4                                               3401
#
#                                            HD01_VD34  \
# 0  Estimate; Total: - Production, transportation,...
# 1                                              36059
# 2                                              29604
# 3                                              25339
# 4                                              31881
#
#                                            HD02_VD34  \
# 0  Margin of Error; Total: - Production, transpor...
# 1                                               3893
# 2                                               4554
# 3                                               4900
# 4                                               2317
#
#                                            HD01_VD35  \
# 0  Estimate; Total: - Production, transportation,...
# 1                                              47266
# 2                                              35504
# 3                                              37282
# 4                                              26580
#
#                                            HD02_VD35  \
# 0  Margin of Error; Total: - Production, transpor...
# 1                                              13608
# 2                                               6260
# 3                                               6017
# 4                                               2901
#
#                                            HD01_VD36  \
# 0  Estimate; Total: - Production, transportation,...
# 1                                              19076
# 2                                              24182
# 3                                              16607
# 4                                              23479
#
#                                            HD02_VD36
# 0  Margin of Error; Total: - Production, transpor...
# 1                                               4808
# 2                                               3580
# 3                                               3497
# 4                                               4942
#
# [5 rows x 75 columns]

# %% [markdown]
# ### Notice the first row is descriptions of the variables

# %% [markdown]
# We could manually remove:

# %%
df = df.drop(0)
df.head(2)
# Out:
#            GEO.id GEO.id2        GEO.display-label HD01_VD01 HD02_VD01  \
# 1  0500000US01001   01001  Autauga County, Alabama     33267      2306
# 2  0500000US01003   01003  Baldwin County, Alabama     31540       683
#
#   HD01_VD02 HD02_VD02 HD01_VD03 HD02_VD03 HD01_VD04    ...    HD01_VD32  \
# 1     48819      1806     55557      4972     63333    ...        31402
# 2     49524      1811     57150      6980     63422    ...        35603
#
#   HD02_VD32 HD01_VD33 HD02_VD33 HD01_VD34 HD02_VD34 HD01_VD35 HD02_VD35  \
# 1      5135     35594      3034     36059      3893     47266     13608
# 2      3882     30549      1606     29604      4554     35504      6260
#
#   HD01_VD36 HD02_VD36
# 1     19076      4808
# 2     24182      3580
#
# [2 rows x 75 columns]

# %% [markdown]
# Or if we knew from the start, we could use the skiprows argument:

# %%
df = pd.read_csv('Data/ACS_16_5YR_B24011_with_ann.csv', skiprows=1, nrows=100)
df.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama             33267
# 1  0500000US01003  1003  Baldwin County, Alabama             31540
# 2  0500000US01005  1005  Barbour County, Alabama             26575
# 3  0500000US01007  1007     Bibb County, Alabama             30088
# 4  0500000US01009  1009   Blount County, Alabama             34900
#
#    Margin of Error; Total:  \
# 0                     2306
# 1                      683
# 2                     1653
# 3                     2224
# 4                     2063
#
#    Estimate; Total: - Management, business, science, and arts occupations:  \
# 0                                              48819
# 1                                              49524
# 2                                              41652
# 3                                              40787
# 4                                              46593
#
#    Margin of Error; Total: - Management, business, science, and arts occupations:  \
# 0                                               1806
# 1                                               1811
# 2                                               2638
# 3                                               2896
# 4                                               2963
#
#    Estimate; Total: - Management, business, science, and arts occupations: - Management, business, and financial occupations:  \
# 0                                              55557
# 1                                              57150
# 2                                              51797
# 3                                              50069
# 4                                              47003
#
#    Margin of Error; Total: - Management, business, science, and arts occupations: - Management, business, and financial occupations:  \
# 0                                               4972
# 1                                               6980
# 2                                               5980
# 3                                              12841
# 4                                               6189
#
#    Estimate; Total: - Management, business, science, and arts occupations: - Management, business, and financial occupations: - Management occupations  \
# 0                                              63333
# 1                                              63422
# 2                                              52775
# 3                                              67917
# 4                                              50991
#
#                                                           ...                                                           \
# 0                                                         ...
# 1                                                         ...
# 2                                                         ...
# 3                                                         ...
# 4                                                         ...
#
#    Estimate; Total: - Natural resources, construction, and maintenance occupations: - Installation, maintenance, and repair occupations  \
# 0                                              31402
# 1                                              35603
# 2                                              37847
# 3                                              45952
# 4                                              42489
#
#    Margin of Error; Total: - Natural resources, construction, and maintenance occupations: - Installation, maintenance, and repair occupations  \
# 0                                               5135
# 1                                               3882
# 2                                              11189
# 3                                               5622
# 4                                               7176
#
#    Estimate; Total: - Production, transportation, and material moving occupations:  \
# 0                                              35594
# 1                                              30549
# 2                                              26094
# 3                                              28983
# 4                                              32969
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations:  \
# 0                                               3034
# 1                                               1606
# 2                                               4884
# 3                                               3401
# 4                                               3767
#
#   Estimate; Total: - Production, transportation, and material moving occupations: - Production occupations  \
# 0                                              36059
# 1                                              29604
# 2                                              25339
# 3                                              31881
# 4                                              31814
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations: - Production occupations  \
# 0                                               3893
# 1                                               4554
# 2                                               4900
# 3                                               2317
# 4                                               4551
#
#   Estimate; Total: - Production, transportation, and material moving occupations: - Transportation occupations  \
# 0                                              47266
# 1                                              35504
# 2                                              37282
# 3                                              26580
# 4                                              41375
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations: - Transportation occupations  \
# 0                                              13608
# 1                                               6260
# 2                                               6017
# 3                                               2901
# 4                                               5280
#
#   Estimate; Total: - Production, transportation, and material moving occupations: - Material moving occupations  \
# 0                                              19076
# 1                                              24182
# 2                                              16607
# 3                                              23479
# 4                                              26755
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations: - Material moving occupations
# 0                                               4808
# 1                                               3580
# 2                                               3497
# 3                                               4942
# 4                                               2963
#
# [5 rows x 75 columns]

# %% [markdown]
# ## Header
#
# Relatedly to skiprows is the header option. This specifies the row where column names are and starts the load from that point:

# %%
# !head Data/ACS_16_5YR_B24011_with_ann.csv
# Out:
# GEO.id,GEO.id2,GEO.display-label,HD01_VD01,HD02_VD01,HD01_VD02,HD02_VD02,HD01_VD03,HD02_VD03,HD01_VD04,HD02_VD04,HD01_VD05,HD02_VD05,HD01_VD06,HD02_VD06,HD01_VD07,HD02_VD07,HD01_VD08,HD02_VD08,HD01_VD09,HD02_VD09,HD01_VD10,HD02_VD10,HD01_VD11,HD02_VD11,HD01_VD12,HD02_VD12,HD01_VD13,HD02_VD13,HD01_VD14,HD02_VD14,HD01_VD15,HD02_VD15,HD01_VD16,HD02_VD16,HD01_VD17,HD02_VD17,HD01_VD18,HD02_VD18,HD01_VD
te
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeErrorTraceback (most recent call last)
# <ipython-input-8-79cec046d704> in <module>()
# ----> 1 df = pd.read_csv('Data/ACS_16_5YR_B24011_with_ann.csv', header=2)
#       2 df.head()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 2: invalid continuation byte

# %% [markdown]
# ## Encoding
#
# Encoding errors like the one above are always frustrating. This has to do with how the strings within the file itself are formatted. The most common encoding other than `utf-8` that you are likely to come across is `latin-1`.

# %%
df = pd.read_csv('Data/ACS_16_5YR_B24011_with_ann.csv', header=1, encoding='latin-1')
df.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama             33267
# 1  0500000US01003  1003  Baldwin County, Alabama             31540
# 2  0500000US01005  1005  Barbour County, Alabama             26575
# 3  0500000US01007  1007     Bibb County, Alabama             30088
# 4  0500000US01009  1009   Blount County, Alabama             34900
#
#    Margin of Error; Total:  \
# 0                     2306
# 1                      683
# 2                     1653
# 3                     2224
# 4                     2063
#
#    Estimate; Total: - Management, business, science, and arts occupations:  \
# 0                                              48819
# 1                                              49524
# 2                                              41652
# 3                                              40787
# 4                                              46593
#
#    Margin of Error; Total: - Management, business, science, and arts occupations:  \
# 0                                               1806
# 1                                               1811
# 2                                               2638
# 3                                               2896
# 4                                               2963
#
#    Estimate; Total: - Management, business, science, and arts occupations: - Management, business, and financial occupations:  \
# 0                                              55557
# 1                                              57150
# 2                                              51797
# 3                                              50069
# 4                                              47003
#
#    Margin of Error; Total: - Management, business, science, and arts occupations: - Management, business, and financial occupations:  \
# 0                                               4972
# 1                                               6980
# 2                                               5980
# 3                                              12841
# 4                                               6189
#
#   Estimate; Total: - Management, business, science, and arts occupations: - Management, business, and financial occupations: - Management occupations  \
# 0                                              63333
# 1                                              63422
# 2                                              52775
# 3                                              67917
# 4                                              50991
#
#                                                           ...                                                           \
# 0                                                         ...
# 1                                                         ...
# 2                                                         ...
# 3                                                         ...
# 4                                                         ...
#
#   Estimate; Total: - Natural resources, construction, and maintenance occupations: - Installation, maintenance, and repair occupations  \
# 0                                              31402
# 1                                              35603
# 2                                              37847
# 3                                              45952
# 4                                              42489
#
#   Margin of Error; Total: - Natural resources, construction, and maintenance occupations: - Installation, maintenance, and repair occupations  \
# 0                                               5135
# 1                                               3882
# 2                                              11189
# 3                                               5622
# 4                                               7176
#
#   Estimate; Total: - Production, transportation, and material moving occupations:  \
# 0                                              35594
# 1                                              30549
# 2                                              26094
# 3                                              28983
# 4                                              32969
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations:  \
# 0                                               3034
# 1                                               1606
# 2                                               4884
# 3                                               3401
# 4                                               3767
#
#   Estimate; Total: - Production, transportation, and material moving occupations: - Production occupations  \
# 0                                              36059
# 1                                              29604
# 2                                              25339
# 3                                              31881
# 4                                              31814
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations: - Production occupations  \
# 0                                               3893
# 1                                               4554
# 2                                               4900
# 3                                               2317
# 4                                               4551
#
#   Estimate; Total: - Production, transportation, and material moving occupations: - Transportation occupations  \
# 0                                              47266
# 1                                              35504
# 2                                              37282
# 3                                              26580
# 4                                              41375
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations: - Transportation occupations  \
# 0                                              13608
# 1                                               6260
# 2                                               6017
# 3                                               2901
# 4                                               5280
#
#   Estimate; Total: - Production, transportation, and material moving occupations: - Material moving occupations  \
# 0                                              19076
# 1                                              24182
# 2                                              16607
# 3                                              23479
# 4                                              26755
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations: - Material moving occupations
# 0                                               4808
# 1                                               3580
# 2                                               3497
# 3                                               4942
# 4                                               2963
#
# [5 rows x 75 columns]

# %% [markdown]
# ## Selecting Specific Columns
#
# You can also specify specific columns if you only want to load specific features.

# %%
df = pd.read_csv('Data/ACS_16_5YR_B24011_with_ann.csv', usecols=[0,1,2,5,6], encoding='latin-1')
df.head(2)
# Out:
#            GEO.id GEO.id2        GEO.display-label  \
# 0              Id     Id2                Geography
# 1  0500000US01001   01001  Autauga County, Alabama
#
#                                            HD01_VD02  \
# 0  Estimate; Total: - Management, business, scien...
# 1                                              48819
#
#                                            HD02_VD02
# 0  Margin of Error; Total: - Management, business...
# 1                                               1806

# %% [markdown]
# ## Or

# %%
df = pd.read_csv('Data/ACS_16_5YR_B24011_with_ann.csv', usecols=['GEO.id', 'GEO.id2'], encoding='latin-1')
df.head(2)
# Out:
#            GEO.id GEO.id2
# 0              Id     Id2
# 1  0500000US01001   01001

# %% [markdown]
# ## Selecting Specific Sheets
# You can also specify specific sheets for Excel files!

# %%
import pandas as pd

# %% [markdown]
# This can be done by index number

# %%
df1 = pd.read_excel('Data/Yelp_Selected_Businesses.xlsx')
df1.head()
# Out:
#                Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0             business_id       cool        date      funny
# 1  RESDUcs7fIiihp38-d6_6g          0  2015-09-16          0
# 2  RESDUcs7fIiihp38-d6_6g          0  2017-09-09          0
# 3  RESDUcs7fIiihp38-d6_6g          0  2013-01-14          0
# 4  RESDUcs7fIiihp38-d6_6g          0  2017-02-08          0
#
#                Unnamed: 4 Unnamed: 5  \
# 0               review_id      stars
# 1  gkcPdbblTvZDMSwx8nVEKw          5
# 2  mQfl6ci46mu0xaZrkRUhlA          5
# 3  EJ7DJ8bm7-2PLFB9WKx4LQ          3
# 4  lMarDJDg4-e_0YoJOKJoWA          2
#
#                                           Unnamed: 6 Unnamed: 7  \
# 0                                               text     useful
# 1  Got here early on football Sunday 7:30am as I ...          0
# 2  This buffet is amazing.  Yes, it is expensive,...          0
# 3  I was really looking forward to this but it wa...          0
# 4  This place....lol our server was nice.  But fo...          0
#
#                Unnamed: 8
# 0                 user_id
# 1  SKteB5rgDlkkUa1Zxe1N0Q
# 2  f638AHA_GoHbyDB7VFMz7A
# 3  -wVPuTiIEG85LwTK46Prpw
# 4  A21zMqdN76ueLZFpmbue0Q

# %%
df2 = pd.read_excel('Data/Yelp_Selected_Businesses.xlsx', sheet_name=2)
df2.head()
# Out:
#                Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0             business_id       cool        date      funny
# 1  YJ8ljUhLsz6CtT_2ORNFmg          1  2013-04-25          0
# 2  YJ8ljUhLsz6CtT_2ORNFmg          0  2014-07-07          0
# 3  YJ8ljUhLsz6CtT_2ORNFmg          0  2015-12-04          0
# 4  YJ8ljUhLsz6CtT_2ORNFmg          2  2016-07-06          1
#
#                Unnamed: 4 Unnamed: 5  \
# 0               review_id      stars
# 1  xgUz0Ck4_ciNaeIk-H8GBQ          5
# 2  Au7MG4QlAxqq9meyKSQmaw          5
# 3  8IQnZ54nenXjlK-FGZ82Bg          5
# 4  XY42LMhKoXzwtLoku4mvLA          5
#
#                                           Unnamed: 6 Unnamed: 7  \
# 0                                               text     useful
# 1  I loved this place. Easily the most hipsters p...          1
# 2  So my boyfriend and I came here for my birthda...          0
# 3  I really enjoyed their food. Went there for th...          1
# 4  A complete Vegas experience. We arrived right ...          3
#
#                Unnamed: 8
# 0                 user_id
# 1  6cpo8iqgnW3jnozhmY7eAA
# 2  8bFE3u1dMoYXkS7ORqlssw
# 3  bJmE1ms0MyZ6KHjmfZDWGw
# 4  PbccpC-I-8rxzF2bCDh8YA

# %% [markdown]
# Or the name of the sheet itself

# %%
df = pd.read_excel('Data/Yelp_Selected_Businesses.xlsx', sheet_name='Biz_id_RESDU')
df.head()
# Out:
#                Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0             business_id       cool        date      funny
# 1  RESDUcs7fIiihp38-d6_6g          0  2015-09-16          0
# 2  RESDUcs7fIiihp38-d6_6g          0  2017-09-09          0
# 3  RESDUcs7fIiihp38-d6_6g          0  2013-01-14          0
# 4  RESDUcs7fIiihp38-d6_6g          0  2017-02-08          0
#
#                Unnamed: 4 Unnamed: 5  \
# 0               review_id      stars
# 1  gkcPdbblTvZDMSwx8nVEKw          5
# 2  mQfl6ci46mu0xaZrkRUhlA          5
# 3  EJ7DJ8bm7-2PLFB9WKx4LQ          3
# 4  lMarDJDg4-e_0YoJOKJoWA          2
#
#                                           Unnamed: 6 Unnamed: 7  \
# 0                                               text     useful
# 1  Got here early on football Sunday 7:30am as I ...          0
# 2  This buffet is amazing.  Yes, it is expensive,...          0
# 3  I was really looking forward to this but it wa...          0
# 4  This place....lol our server was nice.  But fo...          0
#
#                Unnamed: 8
# 0                 user_id
# 1  SKteB5rgDlkkUa1Zxe1N0Q
# 2  f638AHA_GoHbyDB7VFMz7A
# 3  -wVPuTiIEG85LwTK46Prpw
# 4  A21zMqdN76ueLZFpmbue0Q

# %% [markdown]
# ## Loading a Full Workbook and Previewing Sheet Names
# You can also load an entire excel workbook (which is a collection of spreadsheets) with the `pd.ExcelFile()` method.

# %%
workbook = pd.ExcelFile('Data/Yelp_Selected_Businesses.xlsx')
workbook.sheet_names
# Out:
# ['Biz_id_RESDU',
#  'Biz_id_4JNXU',
#  'Biz_id_YJ8lj',
#  'Biz_id_ujHia',
#  'Biz_id_na4Th']

# %%
df = workbook.parse(sheet_name=1)
df.head()
# Out:
#                Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0             business_id       cool        date      funny
# 1  4JNXUYY8wbaaDmk3BPzlWw          0  2012-06-10          0
# 2  4JNXUYY8wbaaDmk3BPzlWw          0  2012-01-20          0
# 3  4JNXUYY8wbaaDmk3BPzlWw          0  2017-05-10          0
# 4  4JNXUYY8wbaaDmk3BPzlWw          0  2014-05-03          0
#
#                Unnamed: 4 Unnamed: 5  \
# 0               review_id      stars
# 1  wl8BO_I-is-JaMwMW5c_gQ          4
# 2  cf9RrqHY9eQ9M53OPyXLtg          4
# 3  BvmhSQ6WFm2Jxu01G8OpdQ          5
# 4  IoKp9n1489XohTV_-EJ0IQ          5
#
#                                           Unnamed: 6 Unnamed: 7  \
# 0                                               text     useful
# 1  I booked a table here for brunch and it did no...          0
# 2  Came here for lunch after a long night of part...          0
# 3  Loved the fried goat cheese in tomato sauce al...          0
# 4  Love the outdoor atmosphere. Price was right, ...          0
#
#                Unnamed: 8
# 0                 user_id
# 1  fo4mpUqgXL2mJqALc9AvbA
# 2  TVvTtXwPXsvrg2KJGoOUTg
# 3  etbAVunw-4kwr6VTRweZpA
# 4  vKXux2Xx3xcicTgYZoR0pg

# %% [markdown]
# ## Saving Data
# Once we have data loaded that we may want to export back out, we use the **`.to_csv()`** or **`.to_excel()`** methods of any dataframe object.

# %%
df.to_csv('NewSavedView.csv', index=False) #Notice how we have to pass index=False if we do not want it included in our output

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading https://files.pythonhosted.org/packages/ba/06/b899c8867518df19e242d8cbc82d4ba210f5ffbeebb7704c695e687ab59c/openpyxl-2.6.2.tar.gz (173kB)
#     100% |████████████████████████████████| 174kB 33.1MB/s ta 0:00:01
# Collecting jdcal (from openpyxl)
#   Downloading https://files.pythonhosted.org/packages/f0/da/572cbc0bc582390480bbd7c4e93d14dc46079778ed915b505dc494b37c57/jdcal-1.4.1-py2.py3-none-any.whl
# Collecting et_xmlfile (from openpyxl)
#   Downloading https://files.pythonhosted.org/packages/22/28/a99c42aea746e18382ad9fb36f64c1c1f04216f41797f2f0fa567da11388/et_xmlfile-1.0.1.tar.gz
# Building wheels for collected packages: openpyxl, et-xmlfile
#   Running setup.py bdist_wheel for openpyxl ... done
#   Stored in directory: /home/garrulous-chip-7064/.cache/pip/wheels/82/cd/05/2e1db4b561fda743444f9573f2c5090a7b991200c92770dd7a
#   Running setup.py bdist_wheel for et-xmlfile ... done
#   Stored in directory: /home/garrulous-chip-7064/.cache/pip/wheels/2a/77/35/0da0965a057698121fc7d8c5a7a9955cdbfb3cc4e2423cad39
# Successfully built openpyxl et-xmlfile
# smart-open 1.8.0 requires bz2file, which is not installed.
# Installing collected packages: jdcal, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.0.1 jdcal-1.4.1 openpyxl-2.6.2
# You are using pip version 10.0.1, however version 19.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
df.to_excel('NewSavedView.xlsx')
# Out:
# ModuleNotFoundErrorTraceback (most recent call last)
# <ipython-input-19-cf11f83f6ab9> in <module>()
# ----> 1 df.to_excel('NewSavedView.xlsx')
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1764         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1765                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1766                         engine=engine)
#    1767
#    1768     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     644             need_save = False
#     645         else:
# --> 646             writer = ExcelWriter(_stringify_path(writer), engine=engine)
#     647             need_save = True
#     648
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/io/excel.py in __init__(self, path, engine, **engine_kwargs)
#     996     def __init__(self, path, engine=None, **engine_kwargs):
#     997         # Use the openpyxl module as the Excel writer.
# --> 998         from openpyxl.workbook import Workbook
#     999
#    1000         super(_OpenpyxlWriter, self).__init__(path, **engine_kwargs)
#
# ModuleNotFoundError: No module named 'openpyxl'

# %% [markdown]
# ## Summary
#
# We've spent some time looking into how data importing with Pandas works and some of the methods you can use to manage the import and access the data. In the next lesson, lets get some hands on practice!
